# %%
# Current authors: Noah
import pandas as pd 
import re

# %%
df = pd.read_csv('./Data/Training.csv')
# Out:
# /var/folders/vj/7qqljyy57qxcbg0rt4wlqxqr0000gn/T/ipykernel_1750/3825863849.py:1: DtypeWarning: Columns (27,47,50,51,52,53,54,55,56,58,59,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./Data/Training.csv')

# %%
print(df.head(20))
# Out:
#        Match ID 18Char      Completion Date  \
# 0   a1v2J0000028pRvQAI  2017-11-30 00:00:00
# 1   a1v2J0000028pRvQAI  2017-10-31 00:00:00
# 2   a1v2J0000028pRvQAI  2017-12-01 00:00:00
# 3   a1v2J0000028pRvQAI  2017-05-29 00:00:00
# 4   a1v2J0000028pRvQAI  2017-04-30 00:00:00
# 5   a1v2J0000028pRvQAI  2017-06-30 00:00:00
# 6   a1v2J0000028pRvQAI  2017-07-31 00:00:00
# 7   a1v2J0000028pRvQAI  2017-03-30 00:00:00
# 8   a1v2J0000028pRvQAI  2017-10-11 00:00:00
# 9   a1v2J0000028pRvQAI  2017-12-01 00:00:00
# 10  a1v2J000002uR0JQAU  2022-02-11 00:00:00
# 11  a1v2J000002uR0JQAU  2021-06-27 00:00:00
# 12  a1v2J000002uR0JQAU  2021-03-18 00:00:00
# 13  a1v2J000002uR0JQAU  2020-10-28 00:00:00
# 14  a1v2J000002uR0JQAU  2020-05-29 00:00:00
# 15  a1v2J000002uR0JQAU  2019-12-19 00:00:00
# 16  a1v2J000002uR0JQAU  2019-05-14 00:00:00
# 17  a1v2J000002uR0JQAU  2019-04-16 00:00:00
# 18  a1v2J000002uR0JQAU  2019-03-21 00:00:00
# 19  a1v2J000002uR0JQAU  2018-10-30 00:00:00
#
# ...
